# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
from scipy.stats import poisson,skellam
epl_2021 = pd.read_csv(r'/Users/paidioshea/Downloads/PL2021.csv')
epl_2021 = pd.DataFrame(epl_2021, columns=['HomeTeam','AwayTeam','FTHG','FTAG'])
epl_2021 = epl_2021.rename(columns={'FTHG': 'HomeGoals', 'FTAG': 'AwayGoals'})
print(epl_2021)
# Out:
#              HomeTeam     AwayTeam  HomeGoals  AwayGoals
# 0              Fulham      Arsenal          0          3
# 1      Crystal Palace  Southampton          1          0
# 2           Liverpool        Leeds          4          3
# 3            West Ham    Newcastle          0          2
# 4           West Brom    Leicester          0          3
# ..                ...          ...        ...        ...
# 303    Crystal Palace      Chelsea          1          4
# 304           Burnley    Newcastle          1          2
# 305          West Ham    Leicester          3          2
# 306         Tottenham   Man United          1          3
# 307  Sheffield United      Arsenal          0          3
#
# [308 rows x 4 columns]

# %%
epl_2021.mean()
# Out:
# HomeGoals    1.334416
# AwayGoals    1.340909
# dtype: float64

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

goal_model_data = pd.concat([epl_2021[['HomeTeam','AwayTeam','HomeGoals']].assign(home=1).rename(
            columns={'HomeTeam':'team', 'AwayTeam':'opponent','HomeGoals':'goals'}),
           epl_2021[['AwayTeam','HomeTeam','AwayGoals']].assign(home=0).rename(
            columns={'AwayTeam':'team', 'HomeTeam':'opponent','AwayGoals':'goals'})])

poisson_model = smf.glm(formula="goals ~ home + team + opponent", data=goal_model_data, 
                        family=sm.families.Poisson()).fit()
poisson_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  goals   No. Observations:                  616
# Model:                            GLM   Df Residuals:                      576
# Model Family:                 Poisson   Df Model:                           39
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -890.68
# Date:                Mon, 19 Apr 2021   Deviance:                       728.17
# Time:                        17:18:22   Pearson chi2:                     657.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.1294      0.234      0.554      0.580      -0.328       0.587
# team[T.Aston Villa]              0.0055      0.216      0.025      0.980      -0.419       0.430
# team[T.Brighton]                -0.2627      0.232     -1.132      0.258      -0.718       0.192
# team[T.Burnley]                 -0.5516      0.253     -2.184      0.029      -1.047      -0.057
# team[T.Chelsea]                  0.0947      0.209      0.454      0.650      -0.314       0.503
# team[T.Crystal Palace]          -0.2689      0.232     -1.158      0.247      -0.724       0.186
# team[T.Everton]                 -0.0252      0.219     -0.115      0.908      -0.455       0.404
# team[T.Fulham]                  -0.6270      0.255     -2.456      0.014      -1.127      -0.127
# team[T.Leeds]                    0.1465      0.210      0.697      0.486      -0.265       0.558
